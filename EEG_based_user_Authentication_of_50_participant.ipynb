# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Reshape, LSTM, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import numpy as np
import os

# %%
# !pip install pyedflib
# Out:
# Requirement already satisfied: pyedflib in c:\users\akhileshsing2024\appdata\local\anaconda3\lib\site-packages (0.1.38)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\akhileshsing2024\appdata\local\anaconda3\lib\site-packages (from pyedflib) (1.26.4)

# %%
import pyedflib
import numpy as np

def _read_py_function(filename, num_channels=64):
    # Open the EDF file
    f = pyedflib.EdfReader(filename)
    
    # Get the number of channels and the signal labels
    n_channels = f.signals_in_file
    print(f"Total channels in file: {n_channels}")
    
    # Ensure that we are fetching only the desired number of channels (16 in this case)
    if num_channels > n_channels:
        raise ValueError(f"The file contains only {n_channels} channels, but {num_channels} were requested.")
    
    # Initialize eeg_data to store only the first `num_channels`
    eeg_data = np.zeros((num_channels, f.getNSamples()[0]), dtype=np.float32)
    
    # Read only the first `num_channels` channels
    for i in range(num_channels):
        eeg_data[i, :] = f.readSignal(i)

    n_samples = f.getNSamples()[0]
    reminder = int(n_samples % 160)
    
    # Print statement to check values
    print(f"Original n_samples: {n_samples}")
    print(f"Reminder: {reminder}")
    
    n_samples -= reminder
    seconds = int(n_samples / 160)
    
    # Extract person_id from the filename
    path = filename.split("\\")
    person_id = int(path[-1].partition("S")[2].partition("R")[0])
    
    # Create one-hot encoded labels
    label = np.zeros(50, dtype=bool)
    label[person_id-1] = 1
    labels = np.tile(label, (seconds, 1))
    
    # Normalization step
    for i in range(num_channels):
        channel_data = eeg_data[i, :]
        mean_i = np.mean(channel_data)  # Compute mean of channel i
        std_i = np.std(channel_data)    # Compute standard deviation of channel i
        
        if std_i != 0:  # Avoid division by zero
            eeg_data[i, :] = (channel_data - mean_i) / std_i  # Normalize channel i

    # Transpose the data to shape (n_samples, n_channels)
    eeg_data = eeg_data.T
    
    if reminder > 0:
        eeg_data = eeg_data[:-reminder, :]
    
    # Split the data into 160-sample chunks
    intervals = np.linspace(0, n_samples, num=seconds, endpoint=False, dtype=int)
    eeg_data = np.split(eeg_data, intervals)
    del eeg_data[0]
    eeg_data = np.array(eeg_data)
    
    return eeg_data, labels

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split

def load_eeg_data_with_pyedflib(data_path, max_subjects=50):
    # Initialize the global variables
    global subject_data, all_train_data, all_train_labels, all_test_data, all_test_labels
    global train_data, val_data, train_labels, val_labels

    # Initialize the variables before using them
    subject_data = {}
    all_train_data = []
    all_train_labels = []
    all_test_data = []
    all_test_labels = []

    subject_count = 0  # Counter to track the number of subjects processed

    for subject_dir in os.listdir(data_path):
        subject_path = os.path.join(data_path, subject_dir)
        if os.path.isdir(subject_path):
            print(f"Processing subject: {subject_dir}")
            subject_data[subject_dir] = {}
            for recording_file in os.listdir(subject_path):
                recording_path = os.path.join(subject_path, recording_file)
                if recording_file.endswith('.edf'):
                    recording_id = os.path.splitext(recording_file)[0]
                    print(f"Loading recording: {recording_file}")

                    try:
                        #eeg_data, labels = _read_py_function(recording_path)
                        eeg_data, labels = _read_py_function(recording_path)

                        print(f"Data shape after processing: {eeg_data.shape}")
                        print(f"Labels shape: {labels.shape}")

                        train_data, test_data, train_labels, test_labels = train_test_split(
                            eeg_data, labels, test_size=0.1, random_state=42
                        )
                        
                        all_train_data.append(train_data)
                        all_train_labels.append(train_labels)
                        all_test_data.append(test_data)
                        all_test_labels.append(test_labels)

                    except Exception as e:
                        print(f"Error loading {recording_file}: {e}")

            subject_count += 1  # Increment the subject counter

            # Stop processing once the desired number of subjects is reached
            if subject_count >= max_subjects:
                print(f"Processed {max_subjects} subjects. Stopping further processing.")
                break

    print(f"Train data list length: {len(all_train_data)}")
    print(f"Train labels list length: {len(all_train_labels)}")
    print(f"Test data list length: {len(all_test_data)}")
    print(f"Test labels list length: {len(all_test_labels)}")

    if all_train_data and all_train_labels:
        all_train_data = np.concatenate(all_train_data, axis=0)
        all_train_labels = np.concatenate(all_train_labels, axis=0)
    else:
        print("No training data loaded.")
        return None, None, None, None, None, None

    if all_test_data and all_test_labels:
        all_test_data = np.concatenate(all_test_data, axis=0)
        all_test_labels = np.concatenate(all_test_labels, axis=0)
    else:
        print("No test data loaded.")
        return None, None, None, None, None, None

    if len(all_train_data) == 0 or len(all_train_labels) == 0:
        print("No data available for splitting into training and validation sets.")
        return None, None, None, None, None, None

    # Split train data further into training and validation sets
    train_data, val_data, train_labels, val_labels = train_test_split(
        all_train_data, all_train_labels, test_size=0.25, random_state=42
    )

    return train_data, train_labels, val_data, val_labels, all_test_data, all_test_labels

# %%
data_path = r"C:\Users\akhileshsing2024\Downloads\eeg-motor-movementimagery-dataset-1.0.0\files"
train_data, train_labels, val_data, val_labels, test_data, test_labels = load_eeg_data_with_pyedflib(data_path)
# Access global variables directly if needed
print(f"Train data shape: {train_data.shape if train_data is not None else 'None'}")
print(f"Validation data shape: {val_data.shape if val_data is not None else 'None'}")
print(f"Test data shape: {test_data.shape if test_data is not None else 'None'}")
# Out:
# Processing subject: S001
# Loading recording: S001R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S001R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S001R03.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S001R04.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S001R05.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S001R06.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S001R07.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S001R08.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S001R09.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S001R10.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S001R11.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S001R12.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S001R13.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S001R14.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Processing subject: S002
# Loading recording: S002R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S002R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S002R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S002R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S002R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S002R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S002R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S002R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S002R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S002R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S002R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S002R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S002R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S002R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S003
# Loading recording: S003R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S003R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S003R03.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S003R04.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S003R05.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S003R06.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S003R07.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S003R08.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S003R09.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S003R10.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S003R11.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S003R12.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S003R13.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S003R14.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Processing subject: S004
# Loading recording: S004R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S004R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S004R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S004R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S004R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S004R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S004R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S004R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S004R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S004R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S004R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S004R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S004R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S004R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S005
# Loading recording: S005R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S005R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S005R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S005R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S005R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S005R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S005R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S005R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S005R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S005R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S005R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S005R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S005R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S005R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S006
# Loading recording: S006R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S006R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S006R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S006R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S006R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S006R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S006R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S006R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S006R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S006R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S006R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S006R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S006R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S006R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S007
# Loading recording: S007R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S007R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S007R03.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S007R04.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S007R05.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S007R06.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S007R07.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S007R08.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S007R09.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S007R10.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S007R11.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S007R12.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S007R13.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S007R14.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Processing subject: S008
# Loading recording: S008R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S008R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S008R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S008R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S008R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S008R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S008R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S008R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S008R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S008R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S008R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S008R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S008R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S008R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S009
# Loading recording: S009R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S009R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S009R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S009R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S009R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S009R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S009R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S009R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S009R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S009R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S009R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S009R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S009R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S009R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S010
# Loading recording: S010R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S010R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S010R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S010R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S010R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S010R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S010R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S010R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S010R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S010R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S010R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S010R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S010R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S010R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S011
# Loading recording: S011R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S011R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S011R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S011R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S011R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S011R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S011R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S011R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S011R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S011R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S011R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S011R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S011R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S011R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S012
# Loading recording: S012R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S012R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S012R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S012R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S012R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S012R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S012R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S012R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S012R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S012R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S012R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S012R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S012R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S012R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S013
# Loading recording: S013R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S013R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S013R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S013R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S013R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S013R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S013R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S013R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S013R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S013R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S013R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S013R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S013R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S013R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S014
# Loading recording: S014R01.edf
# Total channels in file: 64
# Original n_samples: 9600
# Reminder: 0
# Data shape after processing: (60, 160, 64)
# Labels shape: (60, 50)
# Loading recording: S014R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S014R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S014R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S014R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S014R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S014R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S014R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S014R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S014R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S014R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S014R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S014R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S014R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S015
# Loading recording: S015R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S015R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S015R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S015R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S015R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S015R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S015R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S015R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S015R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S015R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S015R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S015R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S015R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S015R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S016
# Loading recording: S016R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S016R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S016R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S016R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S016R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S016R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S016R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S016R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S016R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S016R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S016R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S016R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S016R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S016R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S017
# Loading recording: S017R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S017R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S017R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S017R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S017R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S017R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S017R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S017R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S017R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S017R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S017R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S017R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S017R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S017R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S018
# Loading recording: S018R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S018R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S018R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S018R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S018R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S018R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S018R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S018R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S018R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S018R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S018R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S018R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S018R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S018R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S019
# Loading recording: S019R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S019R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S019R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S019R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S019R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S019R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S019R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S019R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S019R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S019R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S019R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S019R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S019R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S019R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S020
# Loading recording: S020R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S020R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S020R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S020R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S020R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S020R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S020R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S020R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S020R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S020R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S020R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S020R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S020R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S020R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S021
# Loading recording: S021R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S021R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S021R03.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S021R04.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S021R05.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S021R06.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S021R07.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S021R08.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S021R09.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S021R10.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S021R11.edf
# ...
# Labels shape: (123, 50)
# Loading recording: S044R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S044R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S044R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S044R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S044R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S044R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S044R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S044R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S044R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S044R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S044R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S045
# Loading recording: S045R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S045R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S045R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S045R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S045R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S045R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S045R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S045R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S045R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S045R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S045R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S045R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S045R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S045R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S046
# Loading recording: S046R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S046R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S046R03.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S046R04.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S046R05.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S046R06.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S046R07.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S046R08.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S046R09.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S046R10.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S046R11.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S046R12.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S046R13.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Loading recording: S046R14.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 64)
# Labels shape: (125, 50)
# Processing subject: S047
# Loading recording: S047R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S047R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S047R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S047R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S047R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S047R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S047R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S047R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S047R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S047R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S047R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S047R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S047R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S047R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S048
# Loading recording: S048R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S048R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S048R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S048R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S048R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S048R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S048R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S048R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S048R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S048R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S048R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S048R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S048R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S048R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S049
# Loading recording: S049R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S049R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S049R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S049R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S049R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S049R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S049R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S049R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S049R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S049R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S049R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S049R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S049R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S049R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processing subject: S050
# Loading recording: S050R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S050R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 64)
# Labels shape: (61, 50)
# Loading recording: S050R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S050R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S050R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S050R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S050R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S050R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S050R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S050R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S050R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S050R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S050R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Loading recording: S050R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 64)
# Labels shape: (123, 50)
# Processed 50 subjects. Stopping further processing.
# Train data list length: 700
# Train labels list length: 700
# Test data list length: 700
# Test labels list length: 700
# Train data shape: (53716, 160, 64)
# Validation data shape: (17906, 160, 64)
# Test data shape: (8499, 160, 64)

# %%
import tensorflow as tf

def eeg_biometric_identification_model(input_shape, n_classes, lstm_size=192, keep_prob=0.5):
    inputs = tf.keras.Input(shape=input_shape)

    # 1D Convolutional Layers
    conv1 = tf.keras.layers.Conv1D(filters=128, kernel_size=2, strides=1, padding='same', activation='relu')(inputs)
    conv2 = tf.keras.layers.Conv1D(filters=256, kernel_size=2, strides=1, padding='same', activation='relu')(conv1)
    conv3 = tf.keras.layers.Conv1D(filters=512, kernel_size=2, strides=1, padding='same', activation='relu')(conv2)
    conv4 = tf.keras.layers.Conv1D(filters=1024, kernel_size=2, strides=1, padding='same', activation='relu')(conv3)

    # Flatten the convolution output before feeding into fully connected layers
    flatten = tf.keras.layers.Flatten()(conv4)

    # Fully connected layer with 192 neurons and dropout
    fc1 = tf.keras.layers.Dense(units=192, activation='relu')(flatten)
    dropout_fc1 = tf.keras.layers.Dropout(rate=1 - keep_prob)(fc1)

    # Reshape to (batch_size, timesteps=1, features=192) for LSTM input
    lstm_input = tf.keras.layers.Reshape((1, 192))(dropout_fc1)  

    # Add LSTM layers
    lstm_out = tf.keras.layers.LSTM(units=lstm_size, return_sequences=True)(lstm_input)  # First LSTM layer
    lstm_out = tf.keras.layers.LSTM(units=lstm_size, return_sequences=False)(lstm_out)  # Second LSTM layer

    # Fully connected layers after LSTM
    fc2 = tf.keras.layers.Dense(units=192, activation='relu')(lstm_out)
    fc3 = tf.keras.layers.Dense(units=192, activation='relu')(fc2)

    # Output layer (Softmax for classification)
    output = tf.keras.layers.Dense(n_classes, activation='softmax')(fc3)

    # Create the model
    model = tf.keras.Model(inputs=inputs, outputs=output)

    return model

# Example usage
input_shape = (160, 64)  # 160 samples, 64 channels (1-second EEG recording)
n_classes = 50  # Number of subjects
keep_prob = 0.5  # Dropout rate

model = eeg_biometric_identification_model(input_shape, n_classes, lstm_size=192, keep_prob=keep_prob)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# Summary
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 160, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_12 (Conv1D)              │ (None, 160, 128)       │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_13 (Conv1D)              │ (None, 160, 256)       │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_14 (Conv1D)              │ (None, 160, 512)       │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_15 (Conv1D)              │ (None, 160, 1024)      │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 163840)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 192)            │    31,457,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 192)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_3 (Reshape)             │ (None, 1, 192)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 1, 192)         │       295,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 192)            │       295,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 192)            │        37,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 192)            │        37,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 50)             │         9,650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,527,154 (127.90 MB)
#  Trainable params: 33,527,154 (127.90 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
checkpoint_path = "cp-{epoch:04d}.weights.h5"  # Save checkpoints in the current directory
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# Save the initial weights before training (optional)
model.save_weights(checkpoint_path.format(epoch=0))

# Training the model
with tf.device('/GPU:0'):  # Ensure training uses the GPU
    history = model.fit(train_data,train_labels, epochs=120, 
                        validation_data=(val_data, val_labels), 
                        batch_size=80,  
                        callbacks=[cp_callback])
# Out:
# Epoch 1/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.0350 - loss: 3.7620
# Epoch 1: saving model to cp-0001.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 157s 228ms/step - accuracy: 0.0350 - loss: 3.7616 - val_accuracy: 0.1181 - val_loss: 2.8579
# Epoch 2/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.1219 - loss: 2.8590
# Epoch 2: saving model to cp-0002.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 155s 231ms/step - accuracy: 0.1219 - loss: 2.8589 - val_accuracy: 0.1841 - val_loss: 2.5314
# Epoch 3/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.1803 - loss: 2.5608
# Epoch 3: saving model to cp-0003.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 153s 228ms/step - accuracy: 0.1803 - loss: 2.5607 - val_accuracy: 0.2372 - val_loss: 2.2939
# Epoch 4/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.2600 - loss: 2.2327
# Epoch 4: saving model to cp-0004.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 153s 227ms/step - accuracy: 0.2600 - loss: 2.2326 - val_accuracy: 0.3471 - val_loss: 1.9268
# Epoch 5/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.3502 - loss: 1.8636
# Epoch 5: saving model to cp-0005.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 153s 228ms/step - accuracy: 0.3502 - loss: 1.8635 - val_accuracy: 0.4010 - val_loss: 1.6670
# Epoch 6/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.4336 - loss: 1.5761
# Epoch 6: saving model to cp-0006.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 153s 228ms/step - accuracy: 0.4336 - loss: 1.5761 - val_accuracy: 0.4702 - val_loss: 1.4999
# Epoch 7/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.5091 - loss: 1.3620
# Epoch 7: saving model to cp-0007.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 154s 229ms/step - accuracy: 0.5091 - loss: 1.3619 - val_accuracy: 0.5039 - val_loss: 1.4625
# Epoch 8/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.5724 - loss: 1.1929
# Epoch 8: saving model to cp-0008.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 154s 228ms/step - accuracy: 0.5724 - loss: 1.1929 - val_accuracy: 0.5911 - val_loss: 1.2195
# Epoch 9/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.6395 - loss: 1.0175
# Epoch 9: saving model to cp-0009.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 155s 230ms/step - accuracy: 0.6395 - loss: 1.0174 - val_accuracy: 0.6373 - val_loss: 1.1502
# Epoch 10/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.6872 - loss: 0.8890
# Epoch 10: saving model to cp-0010.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 153s 228ms/step - accuracy: 0.6872 - loss: 0.8889 - val_accuracy: 0.6483 - val_loss: 1.1052
# Epoch 11/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.7347 - loss: 0.7706
# Epoch 11: saving model to cp-0011.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 153s 228ms/step - accuracy: 0.7347 - loss: 0.7706 - val_accuracy: 0.6737 - val_loss: 1.1087
# Epoch 12/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.7755 - loss: 0.6618
# Epoch 12: saving model to cp-0012.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 154s 229ms/step - accuracy: 0.7755 - loss: 0.6618 - val_accuracy: 0.7050 - val_loss: 1.0516
# Epoch 13/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.7959 - loss: 0.6056
# Epoch 13: saving model to cp-0013.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 153s 228ms/step - accuracy: 0.7959 - loss: 0.6056 - val_accuracy: 0.6906 - val_loss: 1.0210
# Epoch 14/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.
120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9963 - loss: 0.0126
# Epoch 110: saving model to cp-0110.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 154s 230ms/step - accuracy: 0.9963 - loss: 0.0126 - val_accuracy: 0.9158 - val_loss: 0.4372
# Epoch 111/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9966 - loss: 0.0121
# Epoch 111: saving model to cp-0111.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 154s 230ms/step - accuracy: 0.9966 - loss: 0.0121 - val_accuracy: 0.8765 - val_loss: 0.6725
# Epoch 112/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9962 - loss: 0.0122
# Epoch 112: saving model to cp-0112.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 155s 230ms/step - accuracy: 0.9962 - loss: 0.0122 - val_accuracy: 0.9244 - val_loss: 0.4025
# Epoch 113/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9965 - loss: 0.0131
# Epoch 113: saving model to cp-0113.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 154s 229ms/step - accuracy: 0.9965 - loss: 0.0131 - val_accuracy: 0.9334 - val_loss: 0.3734
# Epoch 114/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9949 - loss: 0.0183
# Epoch 114: saving model to cp-0114.weights.h5
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 154s 229ms/step - accuracy: 0.9949 - loss: 0.0183 - val_accuracy: 0.8842 - val_loss: 0.6194
# Epoch 115/120
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9961 - loss: 0.0105
# Epoch 115: saving model to cp-0115.weights.h5
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[17], line 11
#       9 # Training the model
#      10 with tf.device('/GPU:0'):  # Ensure training uses the GPU
# ---> 11     history = model.fit(train_data,train_labels, epochs=120,
#      12                         validation_data=(val_data, val_labels),
#      13                         batch_size=80,
#      14                         callbacks=[cp_callback])
#
# File c:\Users\akhileshsing2024\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\akhileshsing2024\AppData\Local\anaconda3\Lib\site-packages\h5py\_hl\group.py:483, in Group.__setitem__(self, name, obj)
#     480     htype.commit(self.id, name, lcpl=lcpl)
#     482 else:
# --> 483     ds = self.create_dataset(None, data=obj)
#     484     h5o.link(ds.id, self.id, name, lcpl=lcpl)
#
# File c:\Users\akhileshsing2024\AppData\Local\anaconda3\Lib\site-packages\h5py\_hl\group.py:183, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     180         parent_path, name = name.rsplit(b'/', 1)
#     181         group = self.require_group(parent_path)
# --> 183 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     184 dset = dataset.Dataset(dsid)
#     185 return dset
#
# File c:\Users\akhileshsing2024\AppData\Local\anaconda3\Lib\site-packages\h5py\_hl\dataset.py:166, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter, rdcc_nslots, rdcc_nbytes, rdcc_w0)
#     163 dset_id = h5d.create(parent.id, name, tid, sid, dcpl=dcpl, dapl=dapl)
#     165 if (data is not None) and (not isinstance(data, Empty)):
# --> 166     dset_id.write(h5s.ALL, h5s.ALL, data)
#     168 return dset_id
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5d.pyx:282, in h5py.h5d.DatasetID.write()
#
# File h5py\\_proxy.pyx:115, in h5py._proxy.dset_rw()
#
# OSError: [Errno 28] Can't write data (file write failed: time = Sat Sep 28 02:05:36 2024
# , filename = 'cp-0115.weights.h5', file descriptor = 3, errno = 28, error message = 'No space left on device', buf = 0000029A3480D040, total write size = 125829120, bytes this sub-write = 125829120, bytes actually written = 18446744073709551615, offset = 5597736)

# %%
# Save the training history as a numpy file
np.save("history.npy", history)

# Load the training history
history = np.load("history.npy", allow_pickle=True).item()

# Ensure history is a dictionary
if type(history) is not dict:
    history = history.history

# # Find the epoch with the highest validation accuracy
# max_value = max(history['val_accuracy'])
# print(f"Max Validation Accuracy: {max_value}")

# max_index = history['val_accuracy'].index(max_value)
# print(f"Best Epoch Index: {max_index}")
# print(f"Corresponding Training Accuracy: {history['accuracy'][max_index]}")

# Load the best checkpoint based on validation accuracy
#best_checkpoint_path = "cp-{:04d}.weights.h5".format(max_index)
best_checkpoint_path = "cp-0113.weights.h5"
model.load_weights(best_checkpoint_path)

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(x=test_data, y=test_labels)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.9364 - loss: 0.3086
# Test Loss: 0.3508167862892151
# Test Accuracy: 0.9302271008491516
